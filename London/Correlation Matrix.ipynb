# %%
from pandas import *
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import daniel_utils as du
import datetime
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/daniel/miniconda3/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
df = read_csv(filepath_or_buffer="csv/alletaev.csv", header=0)

df = du.zero_to_nan(df)

df = df.dropna(subset={'L_PREOV', 'L_PERIOD'})

df = du.rename_it_en(df)
df = df.reset_index(drop=True)
df = df[['L_CYCLE', 'L_PREOVULATION', 'L_PERIOD', 'AGE', 'CHILDREN']]

# %%
# %matplotlib inline
print(scatter_matrix(df, diagonal='hist', figsize=(12, 8)))
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7fde53c80be0>
# ...

# %%
df.corr()
# Out:
#                  L_CYCLE  L_PREOVULATION  L_PERIOD       AGE  CHILDREN
# L_CYCLE         1.000000        0.730056  0.137924 -0.119947 -0.028739
# L_PREOVULATION  0.730056        1.000000  0.182941 -0.146998 -0.035387
# L_PERIOD        0.137924        0.182941  1.000000 -0.173131 -0.060737
# AGE            -0.119947       -0.146998 -0.173131  1.000000  0.306728
# CHILDREN       -0.028739       -0.035387 -0.060737  0.306728  1.000000
