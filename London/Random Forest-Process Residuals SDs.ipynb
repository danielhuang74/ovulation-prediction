# %%
# http://scikit-learn.org/stable/auto_examples/ensemble/plot_ensemble_oob.html
import matplotlib.pyplot as plt

import daniel_utils as du

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = []

# %%
with open('random_forest_residuals_sds', 'r') as f:
    data = [float(line.strip()) for line in f.readlines()] # read data, strip the terminal newline character, convert to float

# %%
list_of_n_estimators = list(range(20, 80))

# %%
plt.plot(list_of_n_estimators, data)
plt.xlabel('n_estimators')
plt.ylabel('Residuals standard deviation')
