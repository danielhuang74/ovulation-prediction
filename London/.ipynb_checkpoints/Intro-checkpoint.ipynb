# %% [markdown]
# # Installation
# Nothing here yet

# %% [markdown]
# # Data
#
# There are three data sets: London, Alletaev, and Anomali. Each has the following data fields in common:
#
# * DONNA - unique identifier (number) for each woman
#
# * P_SPEZZ - number of the group of consecutive cycles that the current cycle belongs to (1, 2, ...)
#
# * P_CICLO - number of that cycle within the group
#
# * ANNO_NAS - year of birth (last two digits), incomplete data
#
# * DATA - date of the beginning of the current cycle (DD-MM-YY)
#
# * T_SPEZZ - total number of (groups of) consecutive cycles
#
# * T_CICLI - total number of cycles in the (group of) consecutive cycles that the current cycle belongs to
#
# * QUALIFI - qualification (description) of the current cycle:
#
# ```
# Qualification of the cycle:
# 0 Chart missing (information only available on
# total length)
# 1 Complete information
# 2 Presence on illness
# 3 Chart illegible (information only available
# on total length)
# 4 Cycle monophasic
# 5 Missing critical temperatures so that is
# impossible to identify BBT rise
# ```
#
# * TIPOTEMP - temperature measured in Fahrenheit (1) or Celcius (2)
#
# * L_CICLO - length of the cycle in days
#
# * L_PREOV - number of days before BBT rise
#
# * L_PERIOD - length of period/menstruation

# %% [markdown]
# ## London
#
# Contains data for subjects with all cycles below 100 days
#
# Additional data fields:
#
# * TEMP1...TEMPn - temperature for day n of the cycle (n<=40)

# %% [markdown]
# ## Alletaev
#
# Contains data about the subjects from both the London and Anomali data sets. The Alletaev data set purportedly contains additional data fields (listed below), but the data therein is scarce and mostly incomplete.
#
# Additional data fields:
#
# * ETA - age of subject (date of first cycle - birth date)
# * GG_MATR, MM_MATR, AA_MATR - day, month, year (last two digits) of marriage respectively
# * GG_UL_EV, MM_UL_EV, AA_UL_EV - day, month, year of previous event (what is an event?)
# * FIGLI - number of children
# * GG_n_EV, MM_n_EV, AA_n_EV - day, month, year of nth event (n<=4)

# %% [markdown]
# ## Anomali
#
# Contains all the data for subjects who have had at least one cycle over 100 days

# %%
import pysal as ps
import pandas as pd

# %% [markdown]
# # Import DBF file to pandas data frame
# Code from https://gist.github.com/ryan-hill/f90b1c68f60d12baea81

# %%
from pandas import read_csv
df = read_csv("csv/alletaev.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36641 entries, 0 to 36640
# Data columns (total 32 columns):
# DONNA       36641 non-null int64
# P_SPEZZ     36641 non-null int64
# P_CICLO     36641 non-null int64
# ANNO_NAS    24043 non-null float64
# DATA        34081 non-null object
# T_SPEZZ     36641 non-null int64
# T_CICLI     36641 non-null int64
# QUALIFI     36641 non-null int64
# TIPOTEMP    35872 non-null float64
# L_CICLO     36641 non-null int64
# L_PREOV     29833 non-null float64
# L_PERIOD    34562 non-null float64
# ETA         23199 non-null float64
# GG_MATR     1661 non-null float64
# MM_MATR     2571 non-null float64
# AA_MATR     2598 non-null float64
# GG_UL_EV    3737 non-null float64
# MM_UL_EV    12695 non-null float64
# AA_UL_EV    15456 non-null float64
# FIGLI       22442 non-null float64
# GG_1_EV     2136 non-null float64
# MM_1_EV     4676 non-null float64
# AA_1_EV     1063 non-null float64
# GG_2_EV     270 non-null float64
# ...

# %%
len(df['DONNA'].unique())
# Out:
# 1798

# %%
import math
for index, row in df.iterrows():
    if not(math.isnan(row['FIGLI'])):
        print(row['DONNA'], row['FIGLI'], row['AA_UL_EV'], row['AA_1_EV'], row['AA_2_EV'], row['AA_3_EV'], row['AA_4_EV'])
# Out:
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# 237 1.0 nan nan nan nan nan
# ...

# %% [markdown]
# # The Data
# After ovulation, increased amounts of progesterone are present in the body, which causes Basal Body Temperature (BBT) to rise.
#
# In the data, the `L_PREOV` data field records the number of days (after what?) before BBT rise.
#
# In addition to the fields listed in the LONDON readme file, there are also data fields titled 'TEMP1', 'TEMP2', ... 'TEMP 99' (why?)

# %% [markdown]
# # Background
# http://tesi.cab.unipd.it/24878/1/tesi__maron.pdf
#
# If the egg has been fertilized, manifest different symptoms in women: the temperature, for example, keeps on high values. If you have more than 18 days high temperatures, is almost certainly going to become pregnant: this is the first evidence possible pregnancy. Then, at the period in which it is expected the new menstruation, the temperature generally tends to rise a little, and you may have slight blood loss. In any case, as long as they do not have high 30 measurements, there can be no certainty. There is no fixed number of days between the first day of menstruation and ovulation, while the interval from ovulation until the next menstrual period is not subject to major changes: from 12 to 16 days.
#
# The most widespread possible estimates of the day of ovulation are two: the mucus and the Peak Temperature rise. On the day of the peak it is defined as the last day of the most fertile type mucus; the day Rising of the temperature is the last day of low temperature. both of these estimators of the day of ovulation can be identified only retrospectively

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36139 entries, 0 to 36138
# Columns: 112 entries, DONNA to FIGLI
# dtypes: float64(1), int64(110), object(1)
# memory usage: 30.9+ MB

# %%
from pandas.tools.plotting import scatter_matrix
import matplotlib.pyplot as plt
scatter_matrix(df)
plt.savefig(r"figure_1.png")
#this is not useful
# Out:
# /home/daniel/miniconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py:2787: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=83.0, right=83.0
#   'left=%s, right=%s') % (left, right))
# /home/daniel/miniconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py:2787: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=3.0, right=3.0
#   'left=%s, right=%s') % (left, right))
# /home/daniel/miniconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py:3045: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=83.0, top=83.0
#   'bottom=%s, top=%s') % (bottom, top))
# /home/daniel/miniconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py:3045: UserWarning: Attempting to set identical bottom==top results
# ...
